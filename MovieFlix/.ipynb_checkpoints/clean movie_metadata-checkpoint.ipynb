# %%
import pandas as pd
import numpy as np

import ast

import seaborn as sns
from matplotlib import pyplot
# %matplotlib inline

# %% [markdown]
# # import data and check data types

# %%
# movie = pd.read_csv('movies_metadata.csv',dtype={'popularity':'float64'})
movie = pd.read_csv('movies_metadata.csv',low_memory=False)

# %%
# get the column names
movie.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
# get an overview of the dataset and print the column dtypes
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
print(movie.sample(3))
# Out:
#        adult                              belongs_to_collection    budget  \
# 29639  False  {'id': 52985, 'name': 'Wrong Turn Collection',...   1200000
# 10281  False                                                NaN         0
# 32307  False  {'id': 357173, 'name': 'Sinister Collection', ...  10000000
#
#                                     genres                       homepage  \
# 29639       [{'id': 27, 'name': 'Horror'}]                            NaN
# 10281  [{'id': 99, 'name': 'Documentary'}]                            NaN
# 32307       [{'id': 27, 'name': 'Horror'}]  http://www.sinistermovie.com/
#
#            id    imdb_id original_language             original_title  \
# 29639  259072  tt3612032                en  Wrong Turn 6: Last Resort
# 10281   25975  tt0378407                en          My Date with Drew
# 32307  283445  tt2752772                en                 Sinister 2
#
#                                                 overview  ... release_date  \
# 29639  A sudden and mysterious inheritance brings Dan...  ...   2014-08-22
# 10281  Ever since the second grade when he first saw ...  ...   2005-08-05
# 32307  A young mother and her twin sons move into a r...  ...   2015-08-19
#
#           revenue runtime                          spoken_languages    status  \
# 29639         0.0    91.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 10281         0.0    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 32307  52882018.0    97.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                              tagline                      title  video  \
# 29639                            NaN  Wrong Turn 6: Last Resort  False
# 10281                            NaN          My Date with Drew  False
# 32307  Be careful, children at play.                 Sinister 2  False
#
#       vote_average vote_count
# 29639          4.6      171.0
# 10281          6.3       16.0
# 32307          5.5      605.0
#
# [3 rows x 24 columns]

# %% [markdown]
# # remove duplicate rows

# %%
# find duplicate data
duplicate = movie[movie.duplicated()]
duplicate
# Out:
#        adult                              belongs_to_collection  budget  \
# 1465   False                                                NaN       0
# 9165   False                                                NaN       0
# 9327   False                                                NaN       0
# 13375  False                                                NaN       0
# 16764  False                                                NaN       0
# 21165  False                                                NaN       0
# 21854  False                                                NaN       0
# 22151  False                                                NaN       0
# 23044  False                                                NaN       0
# 24844  False                                                NaN       0
# 28860  False                                                NaN       0
# 29374  False                                                NaN       0
# 35798  False  {'id': 158365, 'name': 'Why We Fight', 'poster...       0
# 38871  False                                                NaN       0
# 40040  False                                                NaN  980000
# 40276  False                                                NaN       0
# 45265  False                                                NaN       0
#
#                                                   genres  \
# 1465   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 9165   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 9327   [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 13375  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 16764  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 21165  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 21854  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 22151  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 23044                      [{'id': 18, 'name': 'Drama'}]
# 24844  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 28860  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 29374  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 35798                [{'id': 99, 'name': 'Documentary'}]
# 38871  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 40040  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 40276                     [{'id': 35, 'name': 'Comedy'}]
# 45265  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                      homepage      id    imdb_id  \
# 1465                                      NaN  105045  tt0111613
# 9165                                      NaN    5511  tt0062229
# 9327                                      NaN   23305  tt0295682
# 13375                                     NaN  141971  tt1180333
# 16764                                     NaN  141971  tt1180333
# 21165                                     NaN  119916  tt0080000
# 21854                                     NaN  152795  tt1821641
# 22151  http://www.daysofdarknessthemovie.com/   18440  tt0499456
# 23044                                     NaN   25541  tt1327820
# 24844            http://www.dealthemovie.com/   11115  tt0446676
# 28860                                     NaN  168538  tt0084387
# 29374                                     NaN   42495  tt0067306
# 35798                                     NaN  159849  tt0173769
# 38871                                     NaN   99080  tt0022537
# 40040                                     NaN  298721  tt2818654
# 40276                                     NaN   97995  tt0127834
# 45265                                     NaN  265189  tt2121382
#
#       original_language                    original_title  \
# 1465                 de                   Das Versprechen
# 9165                 fr                       Le Samouraï
# 9327                 en                       The Warrior
# 13375                fi                          Blackout
# 16764                fi                          Blackout
# 21165                en                       The Tempest
# 21854                en                      The Congress
# 22151                en                  Days of Darkness
# 23044                da                        Broderskab
# 24844                en                              Deal
# 28860                en                              Nana
# 29374                en                         King Lear
# 35798                en  Why We Fight: Divide and Conquer
# 38871                en                        The Viking
# 40040                th                     รักที่ขอนแก่น
# 40276                en              Seven Years Bad Luck
# 45265                sv                            Turist
#
#                                                 overview  ... release_date  \
# 1465   East-Berlin, 1961, shortly after the erection ...  ...   1995-02-16
# 9165   Hitman Jef Costello is a perfectionist who alw...  ...   1967-10-25
# 9327   In feudal India, a warrior (Khan) who renounce...  ...   2001-09-23
# 13375  Recovering from a nail gun shot to the head an...  ...   2008-12-26
# 16764  Recovering from a nail gun shot to the head an...  ...   2008-12-26
# 21165  Prospero, the true Duke of Milan is now living...  ...   1980-02-27
# 21854  More than two decades after catapulting to sta...  ...   2013-05-16
# 22151  When a comet strikes Earth and kicks up a clou...  ...   2007-01-01
# 23044  Former Danish servicemen Lars and Jimmy are th...  ...   2009-10-21
# 24844  As an ex-gambler teaches a hot-shot college ki...  ...   2008-01-29
# 28860  In Zola's Paris, an ingenue arrives at a tony ...  ...   1983-06-13
# 29374  King Lear, old and tired, divides his kingdom ...  ...   1971-02-04
# 35798  The third film of Frank Capra's 'Why We Fight"...  ...   1943-01-01
# 38871  Originally called White Thunder, American prod...  ...   1931-06-21
# 40040  In a hospital, ten soldiers are being treated ...  ...   2015-09-02
# 40276  After breaking a mirror in his home, superstit...  ...   1921-02-06
# 45265  While holidaying in the French Alps, a Swedish...  ...   2014-08-15
#
#          revenue runtime                                   spoken_languages  \
# 1465         0.0   115.0           [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# 9165     39481.0   105.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 9327         0.0    86.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 13375        0.0   108.0             [{'iso_639_1': 'fi', 'name': 'suomi'}]
# 16764        0.0   108.0             [{'iso_639_1': 'fi', 'name': 'suomi'}]
# 21165        0.0   123.0                                                 []
# 21854   455815.0   122.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 22151        0.0    89.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 23044        0.0    90.0             [{'iso_639_1': 'da', 'name': 'Dansk'}]
# 24844        0.0    85.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 28860        0.0    92.0                                                 []
# 29374        0.0   137.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 35798        0.0    57.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 38871        0.0    70.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 40040        0.0   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 40276        0.0    62.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45265  1359497.0   118.0  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
#
#          status                                            tagline  \
# 1465   Released                            A love, a hope, a wall.
# 9165   Released  There is no solitude greater than that of the ...
# 9327   Released                                                NaN
# 13375  Released  Which one is the first to return - memory or t...
# 16764  Released  Which one is the first to return - memory or t...
# 21165  Released                                                NaN
# 21854  Released                                                NaN
# 22151  Released                                                NaN
# 23044  Released                                                NaN
# 24844  Released                                                NaN
# 28860  Released                                                NaN
# 29374   Rumored                                                NaN
# 35798  Released                                                NaN
# 38871  Released  Actually produced during the Great Newfoundlan...
# 40040  Released                                                NaN
# 40276  Released                                                NaN
# 45265  Released                                                NaN
#
#                                   title  video vote_average vote_count
# 1465                        The Promise  False          5.0        1.0
# 9165                        Le Samouraï  False          7.9      187.0
# 9327                        The Warrior  False          6.3       15.0
# 13375                          Blackout  False          6.7        3.0
# 16764                          Blackout  False          6.7        3.0
# 21165                       The Tempest  False          0.0        0.0
# 21854                      The Congress  False          6.4      165.0
# 22151                  Days of Darkness  False          5.0        5.0
# 23044                       Brotherhood  False          7.1       21.0
# 24844                              Deal  False          5.2       22.0
# 28860    Nana, the True Key of Pleasure  False          4.7        3.0
# 29374                         King Lear  False          8.0        3.0
# 35798  Why We Fight: Divide and Conquer  False          5.0        1.0
# 38871                        The Viking  False          0.0        0.0
# 40040             Cemetery of Splendour  False          4.4       50.0
# 40276              Seven Years Bad Luck  False          5.6        4.0
# 45265                     Force Majeure  False          6.8      255.0
#
# [17 rows x 24 columns]

# %%
# remove duplicate data
movie.drop(movie[movie.duplicated()].index,inplace=True)

# %% [markdown]
# # clean irrelevant observations

# %%
movie.status.unique()
# Out:
# array(['Released', nan, 'Rumored', 'Post Production', 'In Production',
#        'Planned', 'Canceled'], dtype=object)

# %%
# filter only released movie
movie=movie[movie.status=='Released']
# mostly na columns and columns with similar information to other columns
movie=movie.drop(columns=['belongs_to_collection','budget','revenue', 'homepage', 'poster_path', 'spoken_languages','status','tagline','original_title'])

# %% [markdown]
# # clean structure errors

# %%
# get an overview of the dataset and print the column dtypes
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44998 entries, 0 to 45465
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 44998 non-null  object
#  1   genres                44998 non-null  object
#  2   id                    44998 non-null  object
#  3   imdb_id               44983 non-null  object
#  4   original_language     44988 non-null  object
#  5   overview              44078 non-null  object
#  6   popularity            44998 non-null  object
#  7   production_companies  44998 non-null  object
#  8   production_countries  44998 non-null  object
#  9   release_date          44920 non-null  object
#  10  runtime               44747 non-null  float64
#  11  title                 44998 non-null  object
#  12  video                 44998 non-null  object
#  13  vote_average          44998 non-null  float64
#  14  vote_count            44998 non-null  float64
# dtypes: float64(3), object(12)
# memory usage: 5.5+ MB

# %%
# adult should be a boolean variable
movie['adult'].unique()
# Out:
# array(['False', 'True'], dtype=object)

# %%
# remove data
movie.drop(movie[movie.adult==' - Written by Ørnås'].index,inplace=True)
movie.drop(movie[movie.adult==' Rune Balot goes to a casino connected to the October corporation to try to wrap up her case once and for all.'].index,inplace=True)
movie.drop(movie[movie.adult==' Avalanche Sharks tells the story of a bikini contest that turns into a horrifying affair when it is hit by a shark avalanche.'].index,inplace=True)

# %%
movie.astype({'adult': 'bool','id':'int64','popularity':'float64'}).dtypes
# Out:
# adult                      bool
# genres                   object
# id                        int64
# imdb_id                  object
# original_language        object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# runtime                 float64
# title                    object
# video                    object
# vote_average            float64
# vote_count              float64
# dtype: object

# %%
movie.drop(movie[movie.popularity=='Beware Of Frost Bites'].index,inplace=True)

# %%
# change dtype of release date  
movie.astype({'release_date':'datetime64[ns]'}).dtypes
# Out:
# adult                           object
# genres                          object
# id                              object
# imdb_id                         object
# original_language               object
# overview                        object
# popularity                      object
# production_companies            object
# production_countries            object
# release_date            datetime64[ns]
# runtime                        float64
# title                           object
# video                           object
# vote_average                   float64
# vote_count                     float64
# dtype: object

# %%
movie['original_language'].unique()
# Out:
# array(['en', 'fr', 'zh', 'it', 'fa', 'nl', 'de', 'cn', 'ar', 'es', 'ru',
#        'sv', 'ja', 'ko', 'sr', 'bn', 'he', 'pt', 'wo', 'ro', 'hu', 'cy',
#        'vi', 'cs', 'da', 'no', 'nb', 'pl', 'el', 'sh', 'xx', 'mk', 'bo',
#        'ca', 'fi', 'th', 'sk', 'bs', 'hi', 'tr', 'is', 'ps', 'ab', 'eo',
#        'ka', 'mn', 'bm', 'zu', 'uk', 'af', 'la', 'et', 'ku', 'fy', 'lv',
#        'ta', 'sl', 'tl', 'ur', 'rw', 'id', 'bg', 'mr', 'lt', 'kk', 'ms',
#        'sq', nan, 'qu', 'te', 'am', 'jv', 'tg', 'ml', 'hr', 'lo', 'ay',
#        'kn', 'eu', 'ne', 'pa', 'ky', 'gl', 'uz', 'sm', 'mt', 'hy', 'iu',
#        'lb', 'si'], dtype=object)

# %%
# change dtype of release date  
movie.astype({'original_language':'category'}).dtypes
# Out:
# adult                     object
# genres                    object
# id                        object
# imdb_id                   object
# original_language       category
# overview                  object
# popularity                object
# production_companies      object
# production_countries      object
# release_date              object
# runtime                  float64
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
movie.sample(3)
# Out:
#       adult                                             genres      id  \
# 5479  False                     [{'id': 27, 'name': 'Horror'}]  318535
# 2075  False  [{'id': 35, 'name': 'Comedy'}, {'id': 9648, 'n...   11219
# 1018  False  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...   11412
#
#         imdb_id original_language  \
# 5479  tt0272730                en
# 2075  tt0048750                en
# 1018  tt0116908                en
#
#                                                overview popularity  \
# 5479  Based on an Edgar Allan Poe story, this film t...   0.006517
# 2075  Trouble erupts in a small, quiet New England t...   6.486117
# 1018  Samantha Caine, suburban homemaker, is the ide...  14.482345
#
#                                    production_companies  \
# 5479           [{'name': 'Roxbury Films', 'id': 58093}]
# 2075  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1018  [{'name': 'New Line Cinema', 'id': 12}, {'name...
#
#                                    production_countries release_date  runtime  \
# 5479                                                 []   2002-03-11     95.0
# 2075  [{'iso_3166_1': 'US', 'name': 'United States o...   1955-10-03     99.0
# 1018  [{'iso_3166_1': 'US', 'name': 'United States o...   1996-10-11    120.0
#
#                         title  video  vote_average  vote_count
# 5479            The Mesmerist  False           0.0         0.0
# 2075   The Trouble with Harry  False           6.9       152.0
# 1018  The Long Kiss Goodnight  False           6.4       323.0

# %% [markdown]
# # handle missing data

# %%
def clean(data):
    nan_value = np.nan
    # find out missing values in quote
    data.replace("", nan_value, inplace=True)
    data.replace(" ", nan_value, inplace=True)
    
    # find out missing values in fresh
    data.replace("none", nan_value, inplace=True)

    # clean fresh and quote by dropping N/As
#     data.dropna(subset=['fresh','quote'],inplace=True)
    
    return data

# %%
clean(movie)
# Out:
#        adult                                             genres      id  \
# 0      False  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      False  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      False  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      False  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4      False                     [{'id': 35, 'name': 'Comedy'}]   11862
# ...      ...                                                ...     ...
# 45461  False  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45462  False                      [{'id': 18, 'name': 'Drama'}]  111109
# 45463  False  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45464  False                                                 []  227506
# 45465  False                                                 []  461257
#
#          imdb_id original_language  \
# 0      tt0114709                en
# 1      tt0113497                en
# 2      tt0113228                en
# 3      tt0114885                en
# 4      tt0113041                en
# ...          ...               ...
# 45461  tt6209470                fa
# 45462  tt2028550                tl
# 45463  tt0303758                en
# 45464  tt0008536                en
# 45465  tt6980792                en
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...  21.946943
# 1      When siblings Judy and Peter discover an encha...  17.015539
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...   3.859495
# 4      Just when George Banks has recovered from his ...   8.387519
# ...                                                  ...        ...
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                                     production_companies  \
# 0         [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1      [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2      [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3      [{'name': 'Twentieth Century Fox Film Corporat...
# 4      [{'name': 'Sandollar Productions', 'id': 5842}...
# ...                                                  ...
# 45461                                                 []
# 45462             [{'name': 'Sine Olivia', 'id': 19653}]
# 45463  [{'name': 'American World Pictures', 'id': 6165}]
# 45464               [{'name': 'Yermoliev', 'id': 88753}]
# 45465                                                 []
#
#                                     production_countries release_date  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-10-30
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-15
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-12-22
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...   1995-02-10
# ...                                                  ...          ...
# 45461             [{'iso_3166_1': 'IR', 'name': 'Iran'}]          NaN
# 45462      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]   2011-11-17
# 45463  [{'iso_3166_1': 'US', 'name': 'United States o...   2003-08-01
# 45464           [{'iso_3166_1': 'RU', 'name': 'Russia'}]   1917-10-21
# 45465   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]   2017-06-09
#
#        runtime                        title  video  vote_average  vote_count
# 0         81.0                    Toy Story  False           7.7      5415.0
# 1        104.0                      Jumanji  False           6.9      2413.0
# 2        101.0             Grumpier Old Men  False           6.5        92.0
# 3        127.0            Waiting to Exhale  False           6.1        34.0
# 4        106.0  Father of the Bride Part II  False           5.7       173.0
# ...        ...                          ...    ...           ...         ...
# 45461     90.0                       Subdue  False           4.0         1.0
# 45462    360.0          Century of Birthing  False           9.0         3.0
# 45463     90.0                     Betrayal  False           3.8         6.0
# 45464     87.0             Satan Triumphant  False           0.0         0.0
# 45465     75.0                     Queerama  False           0.0         0.0
#
# [44998 rows x 15 columns]

# %% [markdown]
# # split datasets

# %%
# genres
genre = movie[["id","genres"]]
# production companies
production_company = movie[['id','production_companies']]
# production countries
production_country = movie[['id','production_countries']]
# remove these columns in movie dataset
movie=movie.drop(columns=['genres','production_companies','production_countries'])

# %% [markdown]
# # typos or inconsistent capitalization

# %%
a4_dims = (15, 10)
fig, ax = pyplot.subplots(figsize=a4_dims)
sns.barplot(ax=ax,x="original_language", y="vote_count", data=movie)

# %% [markdown]
# # export data

# %%
movie.to_csv('movie.csv')
genre.to_csv('genre.csv')
production_company.to_csv('production_company.csv')
production_country.to_csv('production_country.csv')
